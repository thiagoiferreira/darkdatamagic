# %%
import pandas as pd

# %%
s = pd.Series(list('adsfddfugsdfda'))

# %%
s.unique()
# Out:
# array(['a', 'd', 's', 'f', 'u', 'g'], dtype=object)

# %%
s.value_counts()
# Out:
# d    5
# f    3
# a    2
# s    2
# g    1
# u    1
# dtype: int64
