# %%
import pandas as pd

notas = pd.read_csv('ratings.csv')

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ["usuarioID","filmeId", 'nota','momento']
notas.head()
# Out:
#    usuarioID  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas.nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
# 5         3.0
# 6         5.0
# 7         4.0
# 8         5.0
# 9         5.0
# 10        5.0
# 11        5.0
# 12        3.0
# 13        5.0
# 14        4.0
# 15        5.0
# 16        3.0
# 17        3.0
# 18        5.0
# 19        4.0
# 20        4.0
# 21        5.0
# 22        4.0
# 23        3.0
# 24        4.0
# 25        5.0
# 26        4.0
# 27        3.0
# 28        5.0
# 29        4.0
#          ...
# 100806    3.0
# 100807    4.0
# 100808    4.0
# 100809    3.5
# 100810    3.5
# 100811    5.0
# 100812    4.5
# 100813    4.0
# 100814    5.0
# 100815    3.5
# 100816    3.5
# 100817    3.0
# 100818    3.0
# 100819    3.0
# 100820    2.5
# 100821    4.5
# 100822    3.0
# 100823    3.0
# 100824    4.0
# 100825    4.0
# 100826    3.5
# 100827    3.5
# 100828    3.5
# 100829    5.0
# 100830    4.0
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas.nota.head(
)
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.plot(kind='hist')

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(notas.nota)

# %%
filmes = pd.read_csv('movies.csv')
filmes.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
notas.query("filmeId==1")
# Out:
#        usuarioID  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# 1772          18        1   3.5  1455209816
# 2274          19        1   4.0   965705637
# 3219          21        1   3.5  1407618878
# 4059          27        1   3.0   962685262
# 4879          31        1   5.0   850466616
# 4929          32        1   3.0   856736119
# 5031          33        1   3.0   939647444
# 5555          40        1   5.0   832058959
# 6315          43        1   5.0   848993983
# 6429          44        1   3.0   869251860
# 6477          45        1   4.0   951170182
# 6876          46        1   5.0   834787906
# 7112          50        1   3.0  1514238116
# 7931          54        1   3.0   830247330
# 8035          57        1   5.0   965796031
# 9157          63        1   5.0  1443199669
# 9428          64        1   4.0  1161520134
# 9979          66        1   4.0  1104643957
# 10360         68        1   2.5  1158531426
# 11728         71        1   5.0   864737933
# 11808         73        1   4.5  1464196374
# 12264         76        1   0.5  1439165548
# 12412         78        1   4.0  1252575124
# 12730         82        1   2.5  1084467729
# 13402         86        1   4.0  1344082549
# ...          ...      ...   ...         ...
# 84327        541        1   3.0   835643027
# 84603        544        1   3.0   850688537
# 84780        550        1   4.0  1488728441
# 85291        555        1   4.0   978746159
# 85984        559        1   5.0   865095758
# 86124        560        1   3.0  1469653413
# 86582        561        1   4.0  1491094681
# 87087        562        1   4.5  1368893997
# 87791        567        1   3.5  1525286001
# 88219        570        1   4.0  1181476989
# 88522        572        1   4.0   945892484
# 88677        573        1   5.0  1186722182
# 89243        579        1   4.0   958881146
# 89316        580        1   3.0  1167792349
# 89904        584        1   5.0   834987643
# 90256        587        1   5.0   953137847
# 90517        590        1   4.0  1258420408
# 91748        596        1   4.0  1535709666
# 92159        597        1   4.0   941557863
# 92623        599        1   3.0  1498524204
# 95101        600        1   2.5  1237764347
# 95864        601        1   4.0  1521467801
# 96100        603        1   4.0   963178147
# 97043        604        1   3.0   832079851
# 97143        605        1   4.0  1277097561
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
medias_por_filme = notas.groupby('filmeId').mean()['nota']
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')

# %%
sns.boxplot(medias_por_filme)

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.distplot(medias_por_filme, bins=10)

# %%
import matplotlib.pyplot as plt

plt.hist(medias_por_filme)
plt.title('Médias por filme')
# Out:
# Text(0.5, 1.0, 'Médias por filme')

# %%
tmdb  = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
tmdb.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
contagem_lingua = tmdb["original_language"].value_counts().to_frame().reset_index()
contagem_lingua.columns = ['original_language','total']
contagem_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(data = contagem_lingua, x='original_language', y='total')

# %%
sns.catplot(x='original_language',kind = 'count', data=tmdb)

# %%
plt.pie(contagem_lingua['total'],labels = contagem_lingua['original_language'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe18f19a390>,
#   <matplotlib.patches.Wedge at 0x7fe18f19a898>,
#   <matplotlib.patches.Wedge at 0x7fe18f19ad68>,
#   <matplotlib.patches.Wedge at 0x7fe18f123278>,
#   <matplotlib.patches.Wedge at 0x7fe18f123748>,
#   <matplotlib.patches.Wedge at 0x7fe18f123c18>,
#   <matplotlib.patches.Wedge at 0x7fe18f12e128>,
#   <matplotlib.patches.Wedge at 0x7fe18f12e5f8>,
#   <matplotlib.patches.Wedge at 0x7fe18f12eac8>,
#   <matplotlib.patches.Wedge at 0x7fe18f12ef98>,
#   <matplotlib.patches.Wedge at 0x7fe18f1ce320>,
#   <matplotlib.patches.Wedge at 0x7fe18f138940>,
#   <matplotlib.patches.Wedge at 0x7fe18f138e10>,
#   <matplotlib.patches.Wedge at 0x7fe18f142320>,
#   <matplotlib.patches.Wedge at 0x7fe18f1427f0>,
#   <matplotlib.patches.Wedge at 0x7fe18f142cc0>,
#   <matplotlib.patches.Wedge at 0x7fe18f14c1d0>,
#   <matplotlib.patches.Wedge at 0x7fe18f14c6a0>,
#   <matplotlib.patches.Wedge at 0x7fe18f14cb70>,
#   <matplotlib.patches.Wedge at 0x7fe18f155080>,
#   <matplotlib.patches.Wedge at 0x7fe18f155550>,
#   <matplotlib.patches.Wedge at 0x7fe18f155a20>,
#   <matplotlib.patches.Wedge at 0x7fe18f155ef0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0e0400>,
#   <matplotlib.patches.Wedge at 0x7fe18f0e08d0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0e0da0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0e82b0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0e8780>,
#   <matplotlib.patches.Wedge at 0x7fe18f0e8c50>,
#   <matplotlib.patches.Wedge at 0x7fe18f0f1160>,
#   <matplotlib.patches.Wedge at 0x7fe18f0f1630>,
#   <matplotlib.patches.Wedge at 0x7fe18f0f1b00>,
#   <matplotlib.patches.Wedge at 0x7fe18f0f1fd0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0fd4e0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0fd9b0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0fde80>,
#   <matplotlib.patches.Wedge at 0x7fe18f105390>],
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ko'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ru'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'fa'),
#   Text(1.0990363161210686, -0.04603450713357274, 'nl'),
#   Text(1.0992355702663055, -0.04100196411527794, 'he'),
#   Text(1.0993880184234357, -0.03668766750546649, 'th'),
#   Text(1.0995021239019234, -0.033091985965784415, 'id'),
#   Text(1.099584941078101, -0.03021518416739545, 'ar'),
#   Text(1.0996602312343366, -0.027338175536150495, 'ro'),
#   Text(1.099727993855245, -0.024460979766119193, 'cs'),
#   Text(1.0997882284769684, -0.02158361655264929, 'ta'),
#   Text(1.0998284639438185, -0.01942549610642471, 'is'),
#   Text(1.0998529348820232, -0.01798670707495573, 'ky'),
#   Text(1.0998755236058106, -0.01654788726224571, 'nb'),
#   Text(1.0998962300765243, -0.01510903913059323, 'pl'),
#   Text(1.0999150542587282, -0.013670165142345335, 'hu'),
#   Text(1.0999319961202083, -0.012231267759896247, 'te'),
#   Text(1.0999470556319713, -0.01079234944567632, 'ps'),
#   Text(1.099960232768245, -0.00935341266215563, 'sl'),
#   Text(1.0999715275064792, -0.007914459871831963, 'no'),
#   Text(1.0999809398273452, -0.006475493537234394, 'af'),
#   Text(1.0999884697147349, -0.005036516120911278, 'el'),
#   Text(1.0999941171557621, -0.0035975300854338356, 'vi'),
#   Text(1.0999978821407626, -0.0021585378933851127, 'xx'),
#   Text(1.0999997646632929, -0.0007195420073586872, 'tr')])

# %%
total_por_lingua = tmdb['original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc['en']
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles,total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'lingua':['ingles','outros'],
    'total': [total_de_ingles,total_do_resto]
}
dados = pd.DataFrame(dados)
sns.barplot(x='lingua',y='total',data=dados)

# %%
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
plt.pie(dados['total'],labels=dados['lingua'] )
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe18f0980f0>,
#   <matplotlib.patches.Wedge at 0x7fe18f0985c0>],
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()
total_por_lingua_de_outros_filmes
# Out:
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# nl     4
# fa     4
# th     3
# he     3
# ro     2
# id     2
# cs     2
# ar     2
# ta     2
# ps     1
# sl     1
# hu     1
# te     1
# is     1
# pl     1
# xx     1
# vi     1
# af     1
# no     1
# ky     1
# nb     1
# el     1
# tr     1
# Name: original_language, dtype: int64

# %%
sns.catplot(x='original_language',
            kind = 'count', 
            data=total_por_lingua_de_outros_filmes,
            aspect=2, 
            order = total_por_lingua_de_outros_filmes.index
            )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-1631e85c724b> in <module>()
#       3             data=total_por_lingua_de_outros_filmes,
#       4             aspect=2,
# ----> 5             order = total_por_lingua_de_outros_filmes.index
#       6             )
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'original_language'

# %%
filmes.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas.head()
# Out:
#    usuarioID  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas_toy_story = notas.query('filmeId==1')
notas_jumanji = notas.query('filmeId==2')
print(len(notas_toy_story),len(notas_jumanji))
# Out:
# 215 110

# %%
print('Nota média do Toy Story %.2f'%  notas_toy_story.nota.mean())
print('Nota média do Jumanji %.2f'%  notas_jumanji.nota.mean())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43

# %%
print('Mediana do Toy Story %.2f'%  notas_toy_story.nota.median())
print('Mediana do Jumanji %.2f'%  notas_jumanji.nota.median())
# Out:
# Mediana do Toy Story 4.00
# Mediana do Jumanji 3.50

# %%
import numpy as np

filme1 = np.append(np.array([2.5]*10), np.array([3.5]*10))
filme2 = np.append(np.array([5]*10), np.array([1]*10))

# %%
print(filme1.mean())
print(filme2.mean())

print(np.std(filme1))
print(np.std(filme2))

print(np.median(filme1))
print(np.median(filme2))
# Out:
# 3.0
# 3.0
# 0.5
# 2.0
# 3.0
# 3.0

# %%
sns.distplot(filme1)
sns.distplot(filme2)

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(notas_toy_story.nota)

# %%
sns.boxplot(notas_jumanji.nota)

# %%
plt.boxplot([notas_toy_story.nota,notas_jumanji.nota])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe18ca80a20>,
#   <matplotlib.lines.Line2D at 0x7fe18ca8eef0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe18ca8e208>,
#   <matplotlib.lines.Line2D at 0x7fe18ca8e550>,
#   <matplotlib.lines.Line2D at 0x7fe18ca98940>,
#   <matplotlib.lines.Line2D at 0x7fe18ca98c88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe18ca8ebe0>,
#   <matplotlib.lines.Line2D at 0x7fe18ca20358>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe18ca8e898>,
#   <matplotlib.lines.Line2D at 0x7fe18ca98fd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe18ca6d208>,
#   <matplotlib.lines.Line2D at 0x7fe18ca80e80>,
#   <matplotlib.lines.Line2D at 0x7fe18ca982b0>,
#   <matplotlib.lines.Line2D at 0x7fe18ca985f8>]}

# %%
sns.boxplot(x='filmeId',y='nota', data = notas.query('filmeId in [1,2]'))

# %%
notas_toy_story.nota.std()
# Out:
# 0.8348591407114045

# %%
notas_jumanji.nota.std()
# Out:
# 0.8817134921476455
