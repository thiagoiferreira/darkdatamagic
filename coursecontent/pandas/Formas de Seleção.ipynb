# %%
import pandas as pd

# %%
data = [(1, 2, 3, 4),
        (5, 6, 7, 8),
        (8, 10, 11, 12),
        (13, 14, 15, 16)]
df = pd.DataFrame(data, 'l1 l2 l3 l4'.split(), 'c1 c2 c3 c4'.split())

# %%
df['c1']
# Out:
# l1     1
# l2     5
# l3     8
# l4    13
# Name: c1, dtype: int64

# %%
type(df['c1'])
# Out:
# pandas.core.series.Series

# %%
df[['c1','c3']]
# Out:
#     c1  c3
# l1   1   3
# l2   5   7
# l3   8  11
# l4  13  15

# %%
df[1:3]
# Out:
#     c1  c2  c3  c4
# l2   5   6   7   8
# l3   8  10  11  12

# %%
df[1:][['c1','c3']]
# Out:
#     c1  c3
# l2   5   7
# l3   8  11
# l4  13  15

# %%
df
# Out:
#     c1  c2  c3  c4
# l1   1   2   3   4
# l2   5   6   7   8
# l3   8  10  11  12
# l4  13  14  15  16

# %%
df.loc[['l3','l2']]
# Out:
#     c1  c2  c3  c4
# l3   8  10  11  12
# l2   5   6   7   8

# %%
df.loc['l1','c2']
# Out:
# 2

# %%
df.iloc[0,1]
# Out:
# 2

# %%
df.iloc[['l3','l1'],['c4','c1']]
# Out:
#     c4  c1
# l3  12   8
# l1   4   1

# %%
df.iloc[[2,0],[3,0]]
# Out:
#     c4  c1
# l3  12   8
# l1   4   1
